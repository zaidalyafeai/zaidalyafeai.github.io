# %% [markdown]
# # Publications markdown generator for academicpages
#
# Takes a TSV of publications with metadata and converts them for use with [academicpages.github.io](academicpages.github.io). This is an interactive Jupyter notebook ([see more info here](http://jupyter-notebook-beginner-guide.readthedocs.io/en/latest/what_is_jupyter.html)). The core python code is also in `publications.py`. Run either from the `markdown_generator` folder after replacing `publications.tsv` with one containing your data.
#
# TODO: Make this work with BibTex and other databases of citations, rather than Stuart's non-standard TSV format and citation style.

# %% [markdown]
# ## Data format
#
# The TSV needs to have the following columns: pub_date, title, venue, excerpt, citation, site_url, and paper_url, with a header at the top.
#
# - `excerpt` and `paper_url` can be blank, but the others must have values.
# - `pub_date` must be formatted as YYYY-MM-DD.
# - `url_slug` will be the descriptive part of the .md file and the permalink URL for the page about the paper. The .md file will be `YYYY-MM-DD-[url_slug].md` and the permalink will be `https://[yourdomain]/publications/YYYY-MM-DD-[url_slug]`
#
# This is how the raw file looks (it doesn't look pretty, use a spreadsheet or other program to edit and create).

# %%
# !cat publications.tsv
# Out:
# pub_date	title	venue	excerpt	citation	url_slug	paper_url
# 2009-10-01	Paper Title Number 1	Journal 1	This paper is about the number 1. The number 2 is left for future work.	Your Name, You. (2009). "Paper Title Number 1." <i>Journal 1</i>. 1(1).	paper-title-number-1	http://academicpages.github.io/files/paper1.pdf
# 2010-10-01	Paper Title Number 2	Journal 1	This paper is about the number 2. The number 3 is left for future work.	Your Name, You. (2010). "Paper Title Number 2." <i>Journal 1</i>. 1(2).	paper-title-number-2	http://academicpages.github.io/files/paper2.pdf
# 2015-10-01	Paper Title Number 3	Journal 1	This paper is about the number 3. The number 4 is left for future work.	Your Name, You. (2015). "Paper Title Number 3." <i>Journal 1</i>. 1(3).	paper-title-number-3	http://academicpages.github.io/files/paper3.pdf

# %%
from semanticscholar import SemanticScholar
sch = SemanticScholar()
author = sch.get_author(25098419)

# %%
import pandas as pd
keys = ['publicationDate', 'title', 'venue', 'title','citationCount', 'title', 'url' ]
result = []
for paper in author.papers:
    entry = []
    for key in keys:
        entry.append(paper[key])
    result.append(entry)
publications = pd.DataFrame(result, columns= ['pub_date', 'title',	'venue', 'excerpt', 'citation', 'url_slug', 'paper_url'])

# %%
publications.to_csv('publications.tsv', index = False)

# %%
publications = pd.read_csv('publications.tsv')
publications
# Out:
#       pub_date                                              title  \
# 0   2023-03-07  The BigScience ROOTS Corpus: A 1.6TB Composite...
# 1   2022-11-03  Crosslingual Generalization through Multitask ...
# 2   2022-02-02  PromptSource: An Integrated Development Enviro...
# 3   2022-08-01  Masader Plus: A New Interface for Exploring +5...
# 4   2022-01-25  Documenting Geographically and Contextually Di...
# 5   2022-12-04  Network Traffic Classifications using Gated Re...
# 6   2022-11-09  BLOOM: A 176B-Parameter Open-Access Multilingu...
# 7   2021-10-15  Multitask Prompted Training Enables Zero-Shot ...
# 8   2021-06-14  Evaluating Various Tokenizers for Arabic Text ...
# 9   2021-04-01  Arabic Compact Language Modelling for Resource...
# 10  2021-10-13  Masader: Metadata Sourcing for Arabic Text and...
# 11  2021-06-20  Calliar: an online handwritten dataset for Ara...
# 12  2021-12-20  Between words and characters: A Brief History ...
# 13  2020-05-31  A Survey in Transfer Learning in Natural Langa...
# 14  2020-08-01  Meter classification of Arabic poems using dee...
# 15  2020-11-04  MetRec: A dataset for meter classification of ...
# 16  2020-03-01  A fully-automated deep learning pipeline for c...
# 17  2020-11-01  ARBML: Democritizing Arabic Natural Language P...
# 18  2020-05-31  A Survey on Transfer Learning in Natural Langu...
# 19  2017-07-01  Countermeasureing Zero Day Attacks: Asset-Base...
#
#                                                 venue  \
# 0               Neural Information Processing Systems
# 1                                           arXiv.org
# 2   Annual Meeting of the Association for Computat...
# 3                                           arXiv.org
# 4                                           arXiv.org
# 5   International Conference on Computational Inte...
# 6                                           arXiv.org
# 7   International Conference on Learning Represent...
# 8                           Neural Processing Letters
# 9      Workshop on Arabic Natural Language Processing
# 10  International Conference on Language Resources...
# 11            Neural computing & applications (Print)
# 12                                          arXiv.org
# 13                                          arXiv.org
# 14                        Pattern Recognition Letters
# 15                                      Data in Brief
# 16                   Expert systems with applications
# 17                                             NLPOSS
# 18                                          arXiv.org
# 19  International Symposium on High Performance Co...
#
#                                               excerpt  citation  \
# 0   The BigScience ROOTS Corpus: A 1.6TB Composite...        32
# 1   Crosslingual Generalization through Multitask ...        70
# 2   PromptSource: An Integrated Development Enviro...        77
# 3   Masader Plus: A New Interface for Exploring +5...         3
# 4   Documenting Geographically and Contextually Di...         8
# 5   Network Traffic Classifications using Gated Re...         0
# 6   BLOOM: A 176B-Parameter Open-Access Multilingu...       270
# 7   Multitask Prompted Training Enables Zero-Shot ...       567
# 8   Evaluating Various Tokenizers for Arabic Text ...        10
# 9   Arabic Compact Language Modelling for Resource...         1
# 10  Masader: Metadata Sourcing for Arabic Text and...        13
# 11  Calliar: an online handwritten dataset for Ara...         1
# 12  Between words and characters: A Brief History ...        38
# 13  A Survey in Transfer Learning in Natural Langa...         0
# 14  Meter classification of Arabic poems using dee...        12
# 15  MetRec: A dataset for meter classification of ...         2
# 16  A fully-automated deep learning pipeline for c...        76
# 17  ARBML: Democritizing Arabic Natural Language P...         4
# 18  A Survey on Transfer Learning in Natural Langu...        24
# 19  Countermeasureing Zero Day Attacks: Asset-Base...         9
#
#                                              url_slug  \
# 0   The BigScience ROOTS Corpus: A 1.6TB Composite...
# 1   Crosslingual Generalization through Multitask ...
# 2   PromptSource: An Integrated Development Enviro...
# 3   Masader Plus: A New Interface for Exploring +5...
# 4   Documenting Geographically and Contextually Di...
# 5   Network Traffic Classifications using Gated Re...
# 6   BLOOM: A 176B-Parameter Open-Access Multilingu...
# 7   Multitask Prompted Training Enables Zero-Shot ...
# 8   Evaluating Various Tokenizers for Arabic Text ...
# 9   Arabic Compact Language Modelling for Resource...
# 10  Masader: Metadata Sourcing for Arabic Text and...
# 11  Calliar: an online handwritten dataset for Ara...
# 12  Between words and characters: A Brief History ...
# 13  A S URVEY ON T RANSFER L EARNING IN N ATURAL L...
# 14  Meter classification of Arabic poems using dee...
# 15  MetRec: A dataset for meter classification of ...
# 16  A fully-automated deep learning pipeline for c...
# 17  ARBML: Democritizing Arabic Natural Language P...
# 18  A Survey on Transfer Learning in Natural Langu...
# 19  Countermeasureing Zero Day Attacks: Asset-Base...
#
#                                             paper_url
# 0   https://www.semanticscholar.org/paper/d32c9701...
# 1   https://www.semanticscholar.org/paper/6fc01ddb...
# 2   https://www.semanticscholar.org/paper/9b1f4492...
# 3   https://www.semanticscholar.org/paper/c81a8d80...
# 4   https://www.semanticscholar.org/paper/cdc554a3...
# 5   https://www.semanticscholar.org/paper/ebfc54bc...
# 6   https://www.semanticscholar.org/paper/eca35805...
# 7   https://www.semanticscholar.org/paper/17dd3555...
# 8   https://www.semanticscholar.org/paper/4d6f9558...
# 9   https://www.semanticscholar.org/paper/5599a7b4...
# 10  https://www.semanticscholar.org/paper/96b8611c...
# 11  https://www.semanticscholar.org/paper/c5a68061...
# 12  https://www.semanticscholar.org/paper/d617f518...
# 13  https://www.semanticscholar.org/paper/e805a79a...
# 14  https://www.semanticscholar.org/paper/22b9b4ca...
# 15  https://www.semanticscholar.org/paper/22e7c2ca...
# 16  https://www.semanticscholar.org/paper/4a680827...
# 17  https://www.semanticscholar.org/paper/523d9b25...
# 18  https://www.semanticscholar.org/paper/5c09b7be...
# 19  https://www.semanticscholar.org/paper/e08dd7ad...

# %% [markdown]
# ## Escape special characters
#
# YAML is very picky about how it takes a valid string, so we are replacing single and double quotes (and ampersands) with their HTML encoded equivilents. This makes them look not so readable in raw format, but they are parsed and rendered nicely.

# %%
html_escape_table = {
    "&": "&amp;",
    '"': "&quot;",
    "'": "&apos;"
    }

def html_escape(text):
    """Produce entities within text."""
    text = str(text)
    try:
        return "".join(html_escape_table.get(c,c) for c in text)
    except:
        return ""

# %% [markdown]
# ## Creating the markdown files
#
# This is where the heavy lifting is done. This loops through all the rows in the TSV dataframe, then starts to concatentate a big string (```md```) that contains the markdown for each type. It does the YAML metadata first, then does the description for the individual page.

# %%
import os
for row, item in publications.iterrows():
    
    md_filename = str(item.pub_date) + "-" + item.url_slug + ".md"
    html_filename = str(item.pub_date) + "-" + item.url_slug
    year = item.pub_date[:4]
    
    ## YAML variables
    
    md = "---\ntitle: \""   + item.title + '"\n'
    
    md += """collection: publications"""
    
    md += f"\npermalink: '/publication/{html_filename}'"
    
    if len(str(item.excerpt)) > 5:
        md += "\nexcerpt: '" + html_escape(item.excerpt) + "'"
    
    md += "\ndate: " + str(item.pub_date) 
    
    md += "\nvenue: '" + html_escape(item.venue) + "'"
    
    if len(str(item.paper_url)) > 5:
        md += "\npaperurl: '" + item.paper_url + "'"
    
    md += "\nCitations: '" + html_escape(item.citation) + "'"
    
    md += "\n---"
    
    ## Markdown description for individual page
        
    if len(str(item.excerpt)) > 5:
        md += "\n" + html_escape(item.excerpt) + "\n"
    
    if len(str(item.paper_url)) > 5:
        md += "\n[Download paper here](" + item.paper_url + ")\n" 
        
    md += "\nCitations: " + str(item.citation)
    
    md_filename = os.path.basename(md_filename)
       
    with open("../_publications/" + md_filename, 'w') as f:
        f.write(md)

# %%
# !rm ../_publications/*.md

# %% [markdown]
# These files are in the publications directory, one directory below where we're working from.

# %%
# !rm ../_publications/*.md

# %%
# !cat '../_publications/2017-07-01-Countermeasureing Zero Day Attacks: Asset-Based Approach.md'
# Out:
# ---
# title: "Countermeasureing Zero Day Attacks: Asset-Based Approach"
# collection: publications
# permalink: '/publication/2017-07-01-Countermeasureing Zero Day Attacks: Asset-Based Approach'
# excerpt: 'Countermeasureing Zero Day Attacks: Asset-Based Approach'
# date: 2017-07-01
# venue: 'International Symposium on High Performance Computing Systems and Applications'
# paperurl: 'https://www.semanticscholar.org/paper/e08dd7ad111e13cbf634ff73945be58d28abdab2'
# citation: '9'
# ---
# Countermeasureing Zero Day Attacks: Asset-Based Approach
#
# [Download paper here](https://www.semanticscholar.org/paper/e08dd7ad111e13cbf634ff73945be58d28abdab2)
#
# Citations: 9
